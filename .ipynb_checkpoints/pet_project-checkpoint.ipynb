# %%
import pandas as pd
import numpy as np
from descrip import initial_data_check

# %%
steam = pd.read_csv('~/Pet_project/steam_games.csv')

# %%
steam['release_date'] = pd.to_datetime(steam['release_date'], format='%b %d, %Y', errors='coerce')

# %%
steam['publisher'] = steam['publisher'].str.split(',').str[0]

# %%
steam['recent_reviews'] = steam['recent_reviews'].str.split(',').str[0]

# %%
import re

def extract_reviews(text):
    match = re.search(r'\(([\d,]+)\)', str(text))
    if match:
        return int(match.group(1).replace(',', ''))
    return None

# %%
steam['all_reviews'] = steam['all_reviews'].apply(extract_reviews)

# %%
steam.head()
# Out:
#                                                  url types  \
# 0    https://store.steampowered.com/app/379720/DOOM/   app
# 1  https://store.steampowered.com/app/578080/PLAY...   app
# 2  https://store.steampowered.com/app/637090/BATT...   app
# 3    https://store.steampowered.com/app/221100/DayZ/   app
# 4  https://store.steampowered.com/app/8500/EVE_On...   app
#
#                             name  \
# 0                           DOOM
# 1  PLAYERUNKNOWN'S BATTLEGROUNDS
# 2                     BATTLETECH
# 3                           DayZ
# 4                     EVE Online
#
#                                         desc_snippet recent_reviews  \
# 0  Now includes all three premium DLC packs (Unto...  Very Positive
# 1  PLAYERUNKNOWN'S BATTLEGROUNDS is a battle roya...          Mixed
# 2  Take command of your own mercenary outfit of '...          Mixed
# 3  The post-soviet country of Chernarus is struck...          Mixed
# 4  EVE Online is a community-driven spaceship MMO...          Mixed
#
#    all_reviews release_date            developer            publisher  \
# 0      42550.0   2016-05-12          id Software   Bethesda Softworks
# 1     836608.0   2017-12-21     PUBG Corporation     PUBG Corporation
# 2       7030.0   2018-04-24  Harebrained Schemes  Paradox Interactive
# 3     167115.0   2018-12-13  Bohemia Interactive  Bohemia Interactive
# 4      11481.0   2003-05-06                  CCP                  CCP
#
#                                         popular_tags  \
# 0  FPS,Gore,Action,Demons,Shooter,First-Person,Gr...
# 1  Survival,Shooter,Multiplayer,Battle Royale,PvP...
# 2  Mechs,Strategy,Turn-Based,Turn-Based Tactics,S...
# 3  Survival,Zombies,Open World,Multiplayer,PvP,Ma...
# 4  Space,Massively Multiplayer,Sci-fi,Sandbox,MMO...
#
#                                         game_details  \
# 0  Single-player,Multi-player,Co-op,Steam Achieve...
# 1             Multi-player,Online Multi-Player,Stats
# 2  Single-player,Multi-player,Online Multi-Player...
# 3  Multi-player,Online Multi-Player,Steam Worksho...
# 4  Multi-player,Online Multi-Player,MMO,Co-op,Onl...
#
#                                            languages  achievements  \
# 0  English,French,Italian,German,Spanish - Spain,...          54.0
# 1  English,Korean,Simplified Chinese,French,Germa...          37.0
# 2                      English,French,German,Russian         128.0
# 3  English,French,Italian,German,Spanish - Spain,...           NaN
# 4                      English,German,Russian,French           NaN
#
#                                                genre  \
# 0                                             Action
# 1             Action,Adventure,Massively Multiplayer
# 2                          Action,Adventure,Strategy
# 3             Action,Adventure,Massively Multiplayer
# 4  Action,Free to Play,Massively Multiplayer,RPG,...
#
#                                     game_description  \
# 0   About This Game Developed by id software, the...
# 1   About This Game  PLAYERUNKNOWN'S BATTLEGROUND...
# 2   About This Game  From original BATTLETECH/Mec...
# 3   About This Game The post-soviet country of Ch...
# 4                                  About This Game
#
#                                       mature_content  \
# 0                                                NaN
# 1   Mature Content Description  The developers de...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                 minimum_requirements  \
# 0  Minimum:,OS:,Windows 7/8.1/10 (64-bit versions...
# 1  Minimum:,Requires a 64-bit processor and opera...
# 2  Minimum:,Requires a 64-bit processor and opera...
# 3  Minimum:,OS:,Windows 7/8.1 64-bit,Processor:,I...
# 4  Minimum:,OS:,Windows 7,Processor:,Intel Dual C...
#
#                             recommended_requirements original_price  \
# 0  Recommended:,OS:,Windows 7/8.1/10 (64-bit vers...         $19.99
# 1  Recommended:,Requires a 64-bit processor and o...         $29.99
# 2  Recommended:,Requires a 64-bit processor and o...         $39.99
# 3  Recommended:,OS:,Windows 10 64-bit,Processor:,...         $44.99
# 4  Recommended:,OS:,Windows 10,Processor:,Intel i...           Free
#
#   discount_price
# 0         $14.99
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %% [markdown]
# 🧩 Обновлённые задания для pet-проекта
# Уровень 1 — базовая разведка данных
# Загрузить датасет и проверить пропуски, типы данных, описательную статистику.
#
# Посчитать среднюю и медианную цену игр на платформе.
#
# Найти топ-10 самых дорогих игр (без учёта скидок).
#
# Найти топ-10 игр с самым высоким рейтингом Metacritic.
#
# Найти топ-10 игр с наибольшим количеством положительных отзывов.
#
# Уровень 2 — исследовательский анализ
# Построить график зависимости положительных отзывов от цены.
#
# Посмотреть, как влияет размер скидки на количество отзывов.
#
# Исследовать среднюю оценку Metacritic по жанрам.
#
# Посмотреть, какие разработчики и издатели чаще всего выпускают игры на Steam.
#
# Построить распределение игр по годам релиза.
#
# Уровень 3 — более сложная аналитика
# Построить корреляционную матрицу между числовыми признаками (цена, отзывы, скидка, Metacritic и т.д.).
#
# Сформировать критерии для рейтинга игр, учитывающего отзывы, Metacritic и цену.
#
# Посчитать среднее количество владельцев по жанрам.
#
# Найти жанры, где скидки влияют на продажи сильнее всего.
#
# Проанализировать, какие платформы популярнее у пользователей.

# %% [markdown]
# Найти топ-10 самых дорогих игр (без учёта скидок).

# %%
def extract_price(price):
    if isinstance(price, str):
        match = re.search(r'\$([\d\.,]+)', price)
        if match:
            return float(match.group(1).replace(',', ''))
    return np.nan

# %%
steam['original_price_clean'] = steam['original_price'].apply(extract_price)

# %%
top10 = steam.query('types == "app"')\
    [['name', 'types', 'original_price_clean']]\
    .sort_values('original_price_clean', ascending=False)\
    .head(10)

# %%
top10
# Out:
#                                                     name types  \
# 38148    Strata Spaces VR – Professional Edition Upgrade   app
# 26069                          Yatsumitsu Fists of Wrath   app
# 33186                   Super Nitrous Zoomer Sound Track   app
# 33185                       Bathroom Chef Wall Paper Set   app
# 26402                            Morendar: Goblin Slayer   app
# 25444                                  Dungeon Creepster   app
# 33184                          Bathroom Chef Sound Track   app
# 33314  Crankies Workshop: Whirlbot Assembly Wall Pape...   app
# 28002                                       Pain Train 2   app
# 33183                     Honey Comb Home Wall Paper Set   app
#
#        original_price_clean
# 38148                995.00
# 26069                624.74
# 33186                624.74
# 33185                624.74
# 26402                624.74
# 25444                624.74
# 33184                624.74
# 33314                624.74
# 28002                624.74
# 33183                624.74
